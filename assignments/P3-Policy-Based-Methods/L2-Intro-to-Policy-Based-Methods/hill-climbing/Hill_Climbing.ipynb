# %% [markdown]
# # Hill Climbing
#
# ---
#
# In this notebook, we will train hill climbing with adaptive noise scaling with OpenAI Gym's Cartpole environment.

# %% [markdown]
# ### 1. Import the Necessary Packages

# %%
import sys
print("Python %s" % sys.version)
from collections import deque
# Out:
# Python 3.13.3 (main, Apr  8 2025, 19:55:40) [GCC 14.2.0]

# %%
import numpy as np
print("NumPy %s" % np.__version__)
# Out:
# NumPy 2.1.2

# %%
import gymnasium as gym
print("Gymnasium %s" % gym.__version__)
from gymnasium.wrappers import RecordVideo
# Out:
# Gymnasium 1.1.1

# %%
import matplotlib
print("matplotlib %s" % matplotlib.__version__)
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# matplotlib 3.10.1

# %%
from IPython import display

# %% [markdown]
# ### 2. Define the Policy

# %%
class Policy():
    def __init__(self, s_size=4, a_size=2):
        # weights for simple linear policy: state_space x action_space
        self.w = 1e-4*np.random.rand(s_size, a_size)
        
    def forward(self, state):
        x = np.dot(state, self.w)
        return np.exp(x)/sum(np.exp(x))
    
    def act(self, state):
        probs = self.forward(state)
        #action = np.random.choice(2, p=probs) # option 1: stochastic policy
        action = np.argmax(probs)              # option 2: deterministic policy
        return action

# %% [markdown]
# ### 3. Train the Agent with Stochastic Policy Search

# %%
env = gym.make('CartPole-v1', render_mode="rgb_array")
print('observation space:', env.observation_space)
print('action space:', env.action_space)
# Out:
# observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# action space: Discrete(2)

# %%
env
# Out:
# <TimeLimit<OrderEnforcing<PassiveEnvChecker<CartPoleEnv<CartPole-v1>>>>>

# %%
policy = Policy()

# %%
def hill_climbing(n_episodes=1000, max_t=1000, gamma=1.0, 
                  print_every=100, noise_scale=1e-2):
    """Implementation of hill climbing with adaptive noise scaling.
        
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        noise_scale (float): standard deviation of additive noise
    """
    scores_deque = deque(maxlen=100)
    scores = []
    best_R = -np.inf
    best_w = policy.w
    for i_episode in range(1, n_episodes+1):
        rewards = []
        state, info = env.reset(seed=0)
        for t in range(max_t):
            action = policy.act(state)
            state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            rewards.append(reward)
            if done:
                break 
        scores_deque.append(sum(rewards))
        scores.append(sum(rewards))

        discounts = [gamma**i for i in range(len(rewards)+1)]
        R = sum([a*b for a,b in zip(discounts, rewards)])

        if R >= best_R: # found better weights
            best_R = R
            best_w = policy.w
            noise_scale = max(1e-3, noise_scale / 2)
            policy.w += noise_scale * np.random.rand(*policy.w.shape) 
        else: # did not find better weights
            noise_scale = min(2, noise_scale * 2)
            policy.w = best_w + noise_scale * np.random.rand(*policy.w.shape)

        if i_episode % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(
                i_episode, np.mean(scores_deque)))
        if np.mean(scores_deque)>=195.0:
            print('Environment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(
                i_episode-100, np.mean(scores_deque)))
            policy.w = best_w
            break
        
    return scores
            
scores = hill_climbing()
# Out:
# Environment solved in -48 episodes!	Average Score: 195.98

# %% [markdown]
# ### 4. Plot the Scores

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %% [markdown]
# ### 5. Watch a Smart Agent!

# %%
# save video to file
env = RecordVideo(env, video_folder="./gym-results", name_prefix="eval",
                  episode_trigger=lambda x: True)
# Out:
# /home/eka/Workspace/pytorch_arc/pytorch_arc_env/lib/python3.13/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /home/eka/Workspace/DRLND/assignments/P3-Policy-Based-Methods/L2-Intro-to-Policy-Based-Methods/hill-climbing/gym-results folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
plt.figure(figsize=(10,10))
state, info = env.reset(seed=0)
img = plt.imshow(env.render()) # only call this once
for t in range(300):
    img.set_data(env.render()) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    
    action = policy.act(state)
    env.render()
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    if done:
        break 

env.close()

# %% [markdown]
# Convert mp4 file to GIF.

# %%
# %%bash
# ls -l ./gym-results
# Out:
# total 20
# -rw-rw-r-- 1 eka eka 17786 May  4 00:16 eval-episode-0.mp4

# %%
# %%bash
# ffmpeg -i ./gym-results/eval-episode-0.mp4 ./gifs/001.gif
# Out:
# ffmpeg version 7.1.1-1ubuntu1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14 (Ubuntu 14.2.0-17ubuntu3)
#   configuration: --prefix=/usr --extra-version=1ubuntu1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-libmfx --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './gym-results/eval-episode-0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:06.02, start: 0.000000, bitrate: 23 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 600x400, 17 kb/s, 50 fps, 50 tbr, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> gif (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec024a40] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec033c80] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec042ec0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec052100] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec061340] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec070580] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec07f7c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec08ea00] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec09dc40] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec0ace80] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec0bc0c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec0cb300] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec0da540] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec0e9780] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec0f89c0] No accelerated colorspace conversion found from yuv420p to bgr8.
# [swscaler @ 0x7d6fec0148c0] [swscaler @ 0x7d6fec107c00] No accelerated colorspace conversion found from yuv420p to bgr8.
# Output #0, gif, to './gifs/001.gif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: gif, bgr8(pc, gbr/unknown/unknown, progressive), 600x400, q=2-31, 200 kb/s, 50 fps, 100 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 gif
# [out#0/gif @ 0x6510fda03fc0] video:93KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.020958%
# frame=  301 fps=0.0 q=-0.0 Lsize=      93KiB time=00:00:06.02 bitrate= 126.8kbits/s speed= 173x
